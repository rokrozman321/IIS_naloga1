# %%
import pandas as pd
import numpy as np

from sklearn.datasets import fetch_california_housing

from evidently import ColumnMapping

from evidently.report import Report
from evidently.metrics.base_metric import generate_column_metrics
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, DataQualityPreset, RegressionPreset
from evidently.metrics import *

from evidently.test_suite import TestSuite
from evidently.tests.base_test import generate_column_tests
from evidently.test_preset import DataStabilityTestPreset, NoTargetPerformanceTestPreset, RegressionTestPreset
from evidently.tests import *

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
# load data

file1 = "../../data/processed/reference_data.csv" 
file2 = "../../data/processed/current_data.csv" 

reference = pd.read_csv(file1)
current = pd.read_csv(file2)

# %%
reference
# Out:
#                 datetime  temps   no2  pm2.5          o3  pm10
# 0    2023-03-17-00:00:00    3.6   3.0    4.0   66.677136   5.0
# 1    2023-03-17-01:00:00    3.5   3.0    3.0   66.677136   4.0
# 2    2023-03-17-02:00:00    3.1   8.0    2.0   66.677136   3.0
# 3    2023-03-17-03:00:00    2.9   5.0    3.0   66.677136   4.0
# 4    2023-03-17-04:00:00    2.5   2.0    3.0   66.677136   4.0
# ..                   ...    ...   ...    ...         ...   ...
# 187  2023-03-24-19:00:00   14.0  15.0   15.0   92.000000  18.0
# 188  2023-03-24-20:00:00   13.0  19.0   25.0   87.000000  29.0
# 189  2023-03-24-21:00:00   13.0  34.0   26.0   70.000000  30.0
# 190  2023-03-24-22:00:00   13.8  35.0   22.0   60.000000  27.0
# 191  2023-03-24-23:00:00   14.4   5.0    9.0  103.000000  12.0
#
# [192 rows x 6 columns]

# %%
current
# Out:
#                 datetime  temps   no2  pm2.5     o3  pm10
# 0    2023-03-18-00:00:00    4.1   8.0   11.0  100.0  13.0
# 1    2023-03-18-01:00:00    4.2  12.0   10.0   91.0  12.0
# 2    2023-03-18-02:00:00    3.4   9.0   10.0   90.0  12.0
# 3    2023-03-18-03:00:00    2.9   9.0   11.0   88.0  12.0
# 4    2023-03-18-04:00:00    3.3   6.0   10.0   96.0  12.0
# ..                   ...    ...   ...    ...    ...   ...
# 187  2023-03-25-19:00:00   11.9  21.0    6.0   60.0   8.0
# 188  2023-03-25-20:00:00   11.3  14.0    6.0   67.0   8.0
# 189  2023-03-25-21:00:00   10.4   8.0    5.0   76.0   6.0
# 190  2023-03-25-22:00:00    9.3   9.0    3.0   76.0   5.0
# 191  2023-03-25-23:00:00    9.3   7.0    4.0   80.0   5.0
#
# [192 rows x 6 columns]

# %%
report = Report(metrics=[
    DataDriftPreset(), 
])

report.run(reference_data=reference, current_data=current)
report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_04f6ba2759e847988af52ea308d0d947 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "05e80eeb-ba49-444b-90b3-a2d00f66e526", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "Dataset Drift", "label": "Dataset Drift is NOT detected. Dataset drift detection threshold is 0.5"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "1a0a9e97-e307-4ebf-9e39-44dd4485f55d", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "5", "label": "Columns"}, {"value": "0", "label": "Drifted Columns"}, {"value": "0.0", "label": "Share of Drifted Columns"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "b46aecca-79b1-4266-9033-472a13fb3e1f", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Drift Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "big_table", "title": "Drift is detected for 0.0% of columns (0 out of 5).", "size": 2, "id": "47a69bbf-a0f6-4eb0-9aae-8ba85f1dac8d", "details": "", "alertsPosition": "row", "alertStats": null, "params": {"rowsPerPage": 5, "columns": [{"title": "Column", "field": "column_name"}, {"title": "Type", "field": "column_type"}, {"title": "Reference Distribution", "field": "reference_distribution", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Current Distribution", "field": "current_distribution", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Data Drift", "field": "data_drift"}, {"title": "Stat Test", "field": "stattest_name"}, {"title": "Drift Score", "field": "drift_score"}], "data": [{"details": {"parts": [{"title": "DATA DRIFT", "id": "5f297791-d88e-419d-b172-11e844228836", "type": "widget"}, {"title": "DATA DISTRIBUTION", "id": "0d2bc57e-0726-48c5-bab5-1dc3899fd4e4", "type": "widget"}]}, "column_name": "pm2.5", "column_type": "num", "stattest_name": "K-S p_value", "reference_distribution": {"x": [2.0, 6.6, 11.2, 15.799999999999999, 20.4, 25.0, 29.599999999999998, 34.199999999999996, 38.8, 43.4, 48.0], "y": [0.028306159420289856, 0.06453804347826088, 0.035099637681159424, 0.036231884057971016, 0.01698369565217391, 0.013586956521739137, 0.011322463768115949, 0.0011322463768115938, 0.0033967391304347816, 0.006793478260869563]}, "current_distribution": {"x": [3.0, 7.5, 12.0, 16.5, 21.0, 25.5, 30.0, 34.5, 39.0, 43.5, 48.0], "y": [0.03819444444444444, 0.056712962962962965, 0.04513888888888889, 0.03009259259259259, 0.017361111111111112, 0.011574074074074075, 0.011574074074074075, 0.0011574074074074073, 0.003472222222222222, 0.006944444444444444]}, "data_drift": "Not Detected", "drift_score": 1.0}, {"details": {"parts": [{"title": "DATA DRIFT", "id": "2356aa87-79e5-497c-806f-2a1e6740714f", "type": "widget"}, {"title": "DATA DISTRIBUTION", "id": "4a2bf2c8-2df2-4616-aa38-ba257221c407", "type": "widget"}]}, "column_name": "pm10", "column_type": "num", "stattest_name": "K-S p_value", "reference_distribution": {"x": [3.0, 8.3, 13.6, 18.9, 24.2, 29.5, 34.8, 40.1, 45.4, 50.699999999999996, 56.0], "y": [0.026533018867924526, 0.0501179245283019, 0.029481132075471705, 0.03341194968553459, 0.019654088050314465, 0.013757861635220135, 0.005896226415094335, 0.0029481132075471713, 0.0019654088050314474, 0.004913522012578613]}, "current_distribution": {"x": [5.0, 10.1, 15.2, 20.299999999999997, 25.4, 30.5, 35.599999999999994, 40.699999999999996, 45.8, 50.9, 56.0], "y": [0.044934640522875824, 0.050040849673202624, 0.02655228758169936, 0.031658496732026135, 0.015318627450980388, 0.015318627450980409, 0.002042483660130718, 0.0030637254901960775, 0.002042483660130718, 0.005106209150326796]}, "data_drift": "Not Detected", "drift_score": 1.0} ...
#     var additional_graphs_evidently_dashboard_04f6ba2759e847988af52ea308d0d947 = {"5f297791-d88e-419d-b172-11e844228836": {"type": "big_graph", "title": "", "size": 2, "id": "5f297791-d88e-419d-b172-11e844228836", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400", "size": 6}, "mode": "markers", "name": "Current", "x": ["2023-03-18-00:00:00", "2023-03-18-01:00:00", "2023-03-18-02:00:00", "2023-03-18-03:00:00", "2023-03-18-04:00:00", "2023-03-18-05:00:00", "2023-03-18-06:00:00",

# %%
report.as_dict()
report.json()
report.save_html('../../reports/report.html')
report.save_json('../../reports/report.json')

# %%
tests = TestSuite(tests=[
    TestNumberOfColumnsWithMissingValues(),
    TestNumberOfRowsWithMissingValues(),
    TestNumberOfConstantColumns(),
    TestNumberOfDuplicatedRows(),
    TestNumberOfDuplicatedColumns(),
    TestColumnsType(),
    TestNumberOfDriftedColumns(),
])

tests.run(reference_data=reference, current_data=current)
tests
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3 = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "6faeefc1-74e0-4057-9288-8c5c351b04f7", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "7", "label": "Tests"}, {"value": "7", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "e5b3f3c7-6d4c-4704-b65a-c707ff740cd2", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "The Number of Columns With Missing Values", "description": "The number of columns with missing values is 0. The test threshold is lte=0.", "state": "success", "details": {"parts": [{"id": "number_of_columns_with_missing_values", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "The Number of Columns With Missing Values"}}, {"title": "The Number Of Rows With Missing Values", "description": "The number of rows with missing values is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Number Of Rows With Missing Values"}}, {"title": "Number of Constant Columns", "description": "The number of constant columns is 0. The test threshold is lte=0.", "state": "success", "details": {"parts": [{"id": "number_of_constant_cols", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Number of Constant Columns"}}, {"title": "Number of Duplicate Rows", "description": "The number of duplicate rows is 0. The test threshold is eq=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Duplicate Rows"}}, {"title": "Number of Duplicate Columns", "description": "The number of duplicate columns is 0. The test threshold is lte=0.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Duplicate Columns"}}, {"title": "Column Types", "description": "The number of columns with a type mismatch is 0 out of 6.", "state": "success", "details": {"parts": [{"id": "5919bd4a-d198-4077-a087-bd9b1b93e098", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Column Types"}}, {"title": "Number of Drifted Features", "description": "The drift is detected for 0 out of 5 features. The test threshold is lt=1.", "state": "success", "details": {"parts": [{"id": "f0d820b0-ace1-46fd-93e9-d4113ba36714", "title": "Drift Table", "type": "widget"}]}, "groups": {"test_group": "data_drift", "test_type": "Number of Drifted Features"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {"id": "data_quality", "title": "Data Quality", "description": "", "sort_index": 0, "severity": null}, {"id": "regression", "title": "Regression", "description": "", "sort_index": 0, "severity": null}]}, {"id": "test_type", "title": "By test type", "values": []}, {"id": "by_class", "title": "By class", "values": []}]}, "insights": [], "alerts": [], "tabs": [], "widgets" ...
#     var additional_graphs_evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3 = {"number_of_columns_with_missing_values": {"type": "table", "title": "", "size": 2, "id": "eab52668-75c2-432f-af21-9081a7d4448e", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["column name", "current number of missing values", "reference number of missing values"], "data": [["datetime", "0 (0.00%)", "0 (0.00%)"], ["temps", "0 (0.00%)", "0 (0.00%)"], ["no2", "0 (0.00%)", "0 (0.00%)"], ["pm2.5", "0 (0.00%)", "0 (0.00%)"], ["o3", "0 (0.00%)", "0 (0.00%)"], ["pm10", "0 (0.00%)", "0 (0.00%)"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "number_of_constant_cols": {"type": "table", "title": "", "size": 2, "id": "44cebdc0-c051-4325-93f7-ce5994785084", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["column name", "current nunique", "reference nunique"], "data": [["pm2.5", "40", "41"], ["pm10", "43", "46"], ["no2", "48", "50"], ["o3", "79", "77"], ["temps", "99", "111"], ["datetime", "192", "192"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "5919bd4a-d198-4077-a087-bd9b1b93e098": {"type": "table", "title": "", "size": 2, "id": "d5866157-d562-4f00-b3f7-ff615ca0966c", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Column Name", "Actual Type", "Expected Type"], "data": [["datetime", "object_", "object_"], ["temps", "float64", "float64"], ["no2", "float64", "float64"], ["pm2.5", "float64", "float64"], ["o3", "float64", "float64"], ["pm10", "float64", "float64"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "f0d820b0-ace1-46fd-93e9-d4113ba36714": {"type": "table", "title": "", "size": 2, "id": "9a3b00bf-384b-43f5-a507-24d218dd609b", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Feature name", "Stattest", "Drift score", "Threshold", "Data Drift"], "data": [["no2", "K-S p_value", "0.519", "0.05", "Not Detected"], ["o3", "K-S p_value", "0.249", "0.05", "Not Detected"], ["pm10", "K-S p_value", "1.0", "0.05", "Not Detected"], ["pm2.5", "K-S p_value", "1.0", "0.05", "Not Detected"], ["temps", "K-S p_value", "0.368", "0.05", "Not Detected"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3)),
#         "root_evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_e1d304972cb54f6dada3aa6e0f77b2e3">Loading...</div>

# %%
tests.as_dict()
tests.json()
tests.save_html('../../reports/tests.html')
tests.save_json('../../reports/tests.json')

# %%
suite = TestSuite(tests=[
    TestNumberOfColumnsWithMissingValues(),
    TestNumberOfRowsWithMissingValues(),
    TestNumberOfConstantColumns(),
    TestNumberOfDuplicatedRows(),
    TestNumberOfDuplicatedColumns(),
    TestColumnsType(),
    TestNumberOfDriftedColumns(),
    TestColumnDrift('Population'),
    TestShareOfOutRangeValues('Population'),
    DataStabilityTestPreset(),
    RegressionTestPreset()
    
])

suite.run(reference_data=reference, current_data=current)
suite
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFound                            Traceback (most recent call last)
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\metrics\data_drift\column_drift_metric.py:272, in ColumnDriftMetric.calculate(self, data)
#     271 try:
# --> 272     current_feature_data = data.get_current_column(self.column)
#     273 except ColumnNotFound as ex:
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\base_metric.py:99, in InputData.get_current_column(self, column)
#      98     _column = column
# ---> 99 return self._get_by_column_name(self.current_data, self.current_additional_features, _column)
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\base_metric.py:88, in InputData._get_by_column_name(dataset, additional, column)
#      87 if column.name not in dataset.columns:
# ---> 88     raise ColumnNotFound(column.name)
#      89 return dataset[column.name]
#
# ColumnNotFound: Population
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\suite\base_suite.py:110, in Display._repr_html_(self)
#     109 def _repr_html_(self):
# --> 110     dashboard_id, dashboard_info, graphs = self._build_dashboard_info()
#     111     template_params = TemplateParams(
#     112         dashboard_id=dashboard_id,
#     113         dashboard_info=dashboard_info,
#     114         additional_graphs=graphs,
#     115     )
#     116     return self._render(determine_template("auto"), template_params)
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\test_suite\test_suite.py:137, in TestSuite._build_dashboard_info(self)
#     135     renderer.color_options = color_options
#     136     by_status[test_result.status] = by_status.get(test_result.status, 0) + 1
# --> 137     test_results.append(renderer.render_html(test))
#     139 summary_widget = BaseWidgetInfo(
#     140     title="",
#     141     size=2,
#    (...)
#     149     },
#     150 )
#     151 test_suite_widget = BaseWidgetInfo(
#     152     title="",
#     153     type="test_suite",
#    (...)
#     170     additionalGraphs=[],
#     171 )
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\tests\data_drift_tests.py:473, in TestColumnDriftRenderer.render_html(self, obj)
#     471 def render_html(self, obj: TestColumnDrift) -> TestHtmlInfo:
#     472     info = super().render_html(obj)
# --> 473     result = obj.metric.get_result()
#     474     column_name = obj.column_name
#     475     if result.column_type == "text":
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\base_metric.py:131, in Metric.get_result(self)
#     129 result = self.context.metric_results.get(self, None)
#     130 if isinstance(result, ErrorResult):
# --> 131     raise result.exception
#     132 if result is None:
#     133     raise ValueError(f"No result found for metric {self} of type {type(self).__name__}")
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\suite\base_suite.py:309, in Suite.run_checks(self)
#     307 try:
#     308     logging.debug(f"Executing {type(test)}...")
# --> 309     test_results[test] = test.check()
#     310 except BaseException as ex:
#     311     test_results[test] = TestResult(
#     312         name=test.name,
#     313         status=TestResult.ERROR,
#     314         description=f"Test failed with exceptions: {ex}",
#     315         exception=ex,
#     316     )
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\tests\data_drift_tests.py:174, in TestColumnDrift.check(self)
#     173 def check(self):
# --> 174     drift_info = self.metric.get_result()
#     176     p_value = np.round(drift_info.drift_score, 3)
#     177     stattest_name = drift_info.stattest_name
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\base_metric.py:131, in Metric.get_result(self)
#     129 result = self.context.metric_results.get(self, None)
#     130 if isinstance(result, ErrorResult):
# --> 131     raise result.exception
#     132 if result is None:
#     133     raise ValueError(f"No result found for metric {self} of type {type(self).__name__}")
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\suite\base_suite.py:291, in Suite.run_calculate(self, data)
#     289 logging.debug(f"Executing {type(calculation)}...")
#     290 try:
# --> 291     calculations[calculation] = calculation.calculate(data)
#     292 except BaseException as ex:
#     293     calculations[calculation] = ErrorResult(ex)
#
# File d:\Programi\Anaconda\Anaconda\envs\IIS1\lib\site-packages\evidently\metrics\data_drift\column_drift_metric.py:274, in ColumnDriftMetric.calculate(self, data)
#     272     current_feature_data = data.get_current_column(self.column)
#     273 except ColumnNotFound as ex:
# --> 274     raise ValueError(f"Cannot find column '{ex.column_name}' in current dataset")
#     275 try:
#     276     reference_feature_data = data.get_reference_column(self.column)
#
# ValueError: Cannot find column 'Population' in current dataset

# %%
suite.as_dict()
suite.json()
suite.save_html('test_suite.html')
suite.save_json('test_suite.json')
